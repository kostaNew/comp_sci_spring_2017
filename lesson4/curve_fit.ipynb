# %%
import numpy as np
from scipy.optimize import *

import matplotlib.pylab as plt
# %matplotlib inline

# %%
def fun(x, t, y):
    return x[0] + x[1] * np.exp(x[2] * t) - y

x0 = np.array([1.0, 1.0, 0.0])

# %%
points_x = np.array(np.linspace(-100,100,100))  #np.array(np.linspace(-100,100,100))
points_y_real = 2*points_x**2 - 34*points_x + 4 
points_y = points_y_real + np.random.normal(0,4000,len(points_y_real))
plt.scatter(points_x, points_y)

# %%
res_lsq = least_squares(fun, x0, args=(points_x, points_y))
res_lsq
# Out:
#  active_mask: array([ 0.,  0.,  0.])
#         cost: 1382110869.9071045
#          fun: array([  8.96352944e+03,   1.54941838e+03,  -6.67106222e+03,
#          3.33580186e+03,  -5.02198371e+03,  -8.12994676e+03,
#          4.70628712e+03,   7.79653322e+03,   3.97034373e+02,
#         -9.95605534e+03,  -1.23746596e+03,  -8.93648107e+03,
#          3.68905976e+03,  -3.01955305e+02,   4.01498895e+03,
#          2.28365761e+03,  -2.07831563e+03,   2.69603272e+03,
#         -8.51506492e+03,  -1.64923921e+03,  -1.75949315e+03,
#          2.81623540e+03,  -1.50347267e+03,   9.00410888e+02,
#          7.74225922e+02,   2.91835254e+03,   6.46474606e+03,
#         -1.62306265e+03,   2.35814422e+03,  -6.56774424e+03,
#         -5.60666794e+03,   3.35014260e+03,   1.05803530e+03,
#          1.91660586e+03,   1.65510909e+03,  -6.97084489e+02,
#         -1.36306637e+03,  -4.03305325e+03,   6.39854771e+00,
#         -1.59500057e+03,  -1.95224294e+03,   2.90101986e+03,
#          1.32162759e+03,   4.15463644e+03,   3.73362686e+03,
#          1.70883790e+03,   1.03902486e+04,   6.38745497e+03,
#          6.81614627e+03,   6.90137968e+03,   1.32531235e+04,
#          1.78475711e+03,   6.93153313e+03,   2.42987960e+03,
#          2.00640690e+03,  -9.84597641e+01,   1.14239204e+03,
#          2.79292476e+03,   8.89576669e+03,   4.84571716e+03,
#          1.07910906e+04,   4.49967533e+03,   2.65036364e+03,
#          4.45700775e+03,   1.73192451e+03,  -4.76235006e+03,
#          1.70364424e+03,   1.67928744e+03,   6.11223121e+03,
#         -9.77054779e+02,  -2.82764775e+03,  -1.53332244e+03,
#          3.14590913e+03,   6.28213769e+03,  -2.02471321e+03,
#          2.14730423e+03,   1.55107167e+03,  -3.54549302e+03,
#         -9.00508155e+02,  -4.94142147e+02,   2.08782621e+03,
#         -4.46792173e+03,   3.58790589e+03,  -3.71929974e+03,
#         -4.15916083e+03,  -7.03979037e+03,   1.30520545e+03,
#         -3.39374242e+03,  -9.78246347e+03,   5.60887473e+02,
#         -7.36867259e+03,   2.25791854e+03,  -1.12949135e+04,
#         -9.21979284e+03,  -4.66357941e+03,  -8.46410593e+03,
#         -1.38131245e+04,  -6.79864309e+03,  -6.60647558e+03,
#         -1.14459301e+04])
#         grad: array([ -1.47847540e-01,  -5.67860633e+00,  -2.61935273e+06])
#          jac: array([[  1.00000001e+00,   6.84391504e+01,  -2.41397242e+06],
#        [  1.00000001e+00,   6.28387812e+01,  -2.17166073e+06],
#        [  1.00000001e+00,   2.65602879e-02,   8.04348389e+02],
#        [  1.00000001e+00,   2.43868746e-02,   7.55905884e+02],
#        [  9.99999992e-01,   2.23913489e-02,   7.10005310e+02],
#        [  1.00000001e+00,   2.05591753e-02,   6.66555176e+02],
#        [  1.00000001e+00,   1.88768564e-02,   6.25461792e+02],
#        [  1.00000001e+00,   1.73321063e-02,   5.86630371e+02],
#        [  1.00000001e+00,   1.59138503e-02,   5.49965942e+02],
#        [  1.00000001e+00,   1.46113597e-02,   5.15373901e+02]])
#      message: '`ftol` termination condition is satisfied.'
#         nfev: 51
#         njev: 45
#   optimality: 2619352.725271225
#       status: 2
#      success: True
#            x: array([  3.74837058e+03,   3.52717793e+02,  -4.22594504e-02])

# %%
points_y_predict = res_lsq.x[0] + res_lsq.x[1] * np.exp(res_lsq.x[2] * points_x)
plt.scatter(points_x, points_y)
plt.plot(points_x, points_y_predict)

# %%
def fun(x, t, y):
    return x[0] + x[1] * t + x[2] * t**2 - y

x0 = np.array([1.0, 1.0, 0.0])

# %%
points_x = np.array(np.linspace(-100,100,100))  #np.array(np.linspace(-100,100,100))
points_y_real = 2*points_x**2 - 34*points_x + 4 
points_y = points_y_real + np.random.normal(0,4000,len(points_y_real))
plt.scatter(points_x, points_y)

# %%
res_lsq = least_squares(fun, x0, args=(points_x, points_y))
res_lsq
# Out:
#  active_mask: array([ 0.,  0.,  0.])
#         cost: 705903195.78925848
#          fun: array([  3.93866789e+02,  -3.30578379e+03,  -2.02460973e+03,
#          2.66253700e+03,   8.64134169e+02,   1.74938405e+03,
#          9.88756081e+02,   2.48574669e+03,  -4.49223544e+03,
#          1.36316058e+03,  -2.36294594e+03,  -1.45321768e+03,
#          2.38355378e+02,   1.65259830e+03,  -6.14757345e+02,
#         -5.55147337e+02,  -4.14779626e+03,   8.38687131e+02,
#          8.27595472e+03,   1.98361907e+01,   1.01804935e+02,
#          1.73198133e+03,   7.92657620e+02,   4.51291897e+03,
#          3.73610209e+03,  -2.96703973e+03,   2.92217915e+03,
#          1.41557674e+03,  -1.77007307e+03,  -1.67564261e+03,
#          6.42406381e+03,   3.08892568e+02,  -2.00834951e+03,
#         -3.15012440e+03,  -3.02685394e+03,   4.92874726e+03,
#          5.41943976e+02,  -7.26453693e+03,  -1.75261682e+03,
#         -5.53228784e+03,  -5.69536258e+03,   2.01748328e+02,
#         -2.55526984e+03,  -6.81398681e+02,   1.73905770e+03,
#         -3.41692374e+03,  -8.60634070e+02,  -2.27851136e+03,
#         -2.94473272e+03,   2.22224832e+03,  -9.04166585e+03,
#         -3.93119717e+02,  -8.13706344e+02,   4.24241364e+03,
#         -5.82120344e+02,   7.25892458e+03,   3.65454160e+03,
#         -4.82344353e+03,  -4.21829917e+03,   6.33585580e+02,
#         -4.76370963e+03,   5.91120840e+03,   4.35682411e+03,
#          5.24704875e+03,   6.76156961e+03,   4.21873322e+02,
#         -8.17752792e+03,   1.51212892e+03,  -2.70750210e+03,
#          4.98188230e+03,  -2.35920493e+02,  -4.81670955e+03,
#          1.13710255e+04,   2.65260946e+03,   6.30477243e+03,
#          4.42564482e+03,  -2.09533541e+03,  -2.71497527e+02,
#          2.96217642e+03,   1.35398511e+02,  -1.14576743e+03,
#          1.43518528e+03,  -4.36683803e+03,   1.79951368e+03,
#         -4.68844554e+03,   1.09203976e+01,  -3.15631784e+03,
#          2.64740536e+02,  -7.56553405e+03,   2.55397940e+03,
#          1.81440151e+03,  -6.97195435e+03,  -6.63629957e+02,
#          4.37900880e+03,   9.93113003e+02,   7.91152543e+02,
#         -2.04835069e+03,  -5.95808871e+03,   4.00778445e+03,
#          2.04597488e+03])
#         grad: array([ 0.00535462, -0.0293561 , -1.29956549])
#          jac: array([[  1.00000051e+00,  -1.00000001e+02,   1.00000000e+04],
#        [  9.99999349e-01,  -9.79797928e+01,   9.60004070e+03],
#        [  1.00000051e+00,  -9.59595924e+01,   9.20824405e+03],
#        [  1.00000051e+00,  -9.39393920e+01,   8.82460970e+03],
#        [  1.00000051e+00,  -9.19191916e+01,   8.44913790e+03],
#        [  1.00000051e+00,  -8.98989913e+01,   8.08182841e+03],
#        [  1.00000051e+00,  -8.78787909e+01,   7.72268135e+03],
#        [  9.99999349e-01,  -8.58585823e+01,   7.37169672e+03],
#        [  1.00000051e+00,  -8.38383901e+01,   7.02887465e+03],
#        [  9.99999928e-01,  -8.18181815e+01,   6.69421488e+03],
#        [  9.99999928e-01,  -7.97979811e+01,   6.36771754e+03],
#        [  1.00000051e+00,  -7.77777807e+01,   6.04938276e+03],
#        [  9.99999928e-01,  -7.57575721e+01,   5.73921028e+03],
#        [  9.99999928e-01,  -7.37373758e+01,   5.43720029e+03],
#        [  1.00000051e+00,  -7.17171713e+01,   5.14335274e+03],
#        [  1.00000051e+00,  -6.96969709e+01,   4.85766755e+03],
#        [  9.99999928e-01,  -6.76767664e+01,   4.58014486e+03],
#        [  9.99999928e-01,  -6.56565660e+01,   4.31078460e+03],
#        [  9.99999928e-01,  -6.36363657e+01,   4.04958676e+03],
#        [  9.99999928e-01,  -6.16161612e+01,   3.79655136e+03],
#        [  9.99999928e-01,  -5.95959608e+01,   3.55167839e+03],
#        [  1.00000051e+00,  -5.75757604e+01,   3.31496785e+03],
#        [  1.00000022e+00,  -5.55555559e+01,   3.08641974e+03],
#        [  9.99999928e-01,  -5.35353534e+01,   2.86603408e+03],
#        [  9.99999928e-01,  -5.15151510e+01,   2.65381083e+03],
#        [  9.99999928e-01,  -4.94949506e+01,   2.44975004e+03],
#        [  9.99999928e-01,  -4.74747482e+01,   2.25385165e+03],
#        [  9.99999928e-01,  -4.54545437e+01,   2.06611569e+03],
#        [  9.99999928e-01,  -4.34343433e+01,   1.88654219e+03],
#        [  9.99999928e-01,  -4.14141408e+01,   1.71513110e+03],
#        [  9.99999928e-01,  -3.93939404e+01,   1.55188246e+03],
#        [  9.99999928e-01,  -3.73737380e+01,   1.39679625e+03],
#        [  1.00000007e+00,  -3.53535356e+01,   1.24987247e+03],
#        [  1.00000007e+00,  -3.33333331e+01,   1.11111111e+03],
#        [  1.00000007e+00,  -3.13131327e+01,   9.80512209e+02],
#        [  9.99999928e-01,  -2.92929282e+01,   8.58075692e+02],
#        [  1.00000007e+00,  -2.72727268e+01,   7.43801651e+02],
#        [  1.00000022e+00,  -2.52525254e+01,   6.37690041e+02],
#        [  1.00000000e+00,  -2.32323230e+01,   5.39740846e+02],
#        [  9.99999928e-01,  -2.12121205e+01,   4.49954112e+02],
#        [  9.99999928e-01,  -1.91919181e+01,   3.68329747e+02],
#        [  9.99999928e-01,  -1.71717167e+01,   2.94867866e+02],
#        [  1.00000007e+00,  -1.51515152e+01,   2.29568415e+02],
#        [  1.00000000e+00,  -1.31313133e+01,   1.72431384e+02],
#        [  1.00000000e+00,  -1.11111109e+01,   1.23456790e+02],
#        [  9.99999928e-01,  -9.09090894e+00,   8.26446228e+01],
#        [  1.00000000e+00,  -7.07070701e+00,   4.99948975e+01],
#        [  1.00000007e+00,  -5.05050508e+00,   2.55075949e+01],
#        [  1.00000007e+00,  -3.03030366e+00,   9.18273417e+00],
#        [  1.00000007e+00,  -1.01010122e+00,   1.02030380e+00],
#        [  9.99999928e-01,   1.01010019e+00,   1.02031913e+00],
#        [  1.00000000e+00,   3.03030302e+00,   9.18273800e+00],
#        [  1.00000000e+00,   5.05050508e+00,   2.55076026e+01],
#        [  9.99999928e-01,   7.07070752e+00,   4.99949014e+01],
#        [  1.00000000e+00,   9.09090920e+00,   8.26446267e+01],
#        [  1.00000022e+00,   1.11111104e+01,   1.23456805e+02],
#        [  9.99999928e-01,   1.31313138e+01,   1.72431372e+02],
#        [  9.99999928e-01,   1.51515152e+01,   2.29568400e+02],
#        [  1.00000022e+00,   1.71717177e+01,   2.94867874e+02],
#        [  1.00000000e+00,   1.91919191e+01,   3.68329762e+02],
#        [  1.00000022e+00,   2.12121205e+01,   4.49954081e+02],
#        [  9.99999928e-01,   2.32323230e+01,   5.39740846e+02],
#        [  9.99999928e-01,   2.52525254e+01,   6.37690011e+02],
#        [  1.00000022e+00,   2.72727258e+01,   7.43801667e+02],
#        [  9.99999928e-01,   2.92929303e+01,   8.58075692e+02],
#        [  1.00000000e+00,   3.13131312e+01,   9.80512194e+02],
#        [  9.99999928e-01,   3.33333331e+01,   1.11111113e+03],
#        [  1.00000000e+00,   3.53535356e+01,   1.24987246e+03],
#        [  1.00000007e+00,   3.73737370e+01,   1.39679625e+03],
#        [  9.99999928e-01,   3.93939404e+01,   1.55188246e+03],
#        [  1.00000007e+00,   4.14141419e+01,   1.71513111e+03],
#        [  9.99999928e-01,   4.34343453e+01,   1.88654216e+03],
#        [  1.00000051e+00,   4.54545416e+01,   2.06611575e+03],
#        [  9.99999928e-01,   4.74747482e+01,   2.25385165e+03],
#        [  1.00000022e+00,   4.94949486e+01,   2.44975004e+03],
#        [  9.99999928e-01,   5.15151510e+01,   2.65381086e+03],
#        [  9.99999928e-01,   5.35353555e+01,   2.86603405e+03],
#        [  9.99999928e-01,   5.55555559e+01,   3.08641974e+03],
#        [  9.99999928e-01,   5.75757583e+01,   3.31496785e+03],
#        [  1.00000022e+00,   5.95959587e+01,   3.55167842e+03],
#        [  9.99999928e-01,   6.16161612e+01,   3.79655136e+03],
#        [  1.00000022e+00,   6.36363636e+01,   4.04958676e+03],
#        [  9.99999928e-01,   6.56565660e+01,   4.31078460e+03],
#        [  9.99999928e-01,   6.76767685e+01,   4.58014486e+03],
#        [  9.99999928e-01,   6.96969709e+01,   4.85766755e+03],
#        [  9.99999928e-01,   7.17171713e+01,   5.14335274e+03],
#        [  9.99999928e-01,   7.37373758e+01,   5.43720029e+03],
#        [  9.99999928e-01,   7.57575762e+01,   5.73921028e+03],
#        [  1.00000051e+00,   7.77777766e+01,   6.04938276e+03],
#        [  9.99999928e-01,   7.97979811e+01,   6.36771754e+03],
#        [  9.99999928e-01,   8.18181815e+01,   6.69421488e+03],
#        [  9.99999928e-01,   8.38383819e+01,   7.02887459e+03],
#        [  1.00000051e+00,   8.58585823e+01,   7.37169672e+03],
#        [  9.99999928e-01,   8.78787868e+01,   7.72268135e+03],
#        [  9.99999928e-01,   8.98989913e+01,   8.08182835e+03],
#        [  9.99999928e-01,   9.19191916e+01,   8.44913790e+03],
#        [  9.99999928e-01,   9.39393920e+01,   8.82460970e+03],
#        [  1.00000051e+00,   9.59595924e+01,   9.20824405e+03],
#        [  1.00000051e+00,   9.79797928e+01,   9.60004070e+03],
#        [  9.99999349e-01,   1.00000001e+02,   9.99999979e+03]])
#      message: '`ftol` termination condition is satisfied.'
#         nfev: 10
#         njev: 10
#   optimality: 1.2995654866099358
#       status: 2
#      success: True
#            x: array([ 211.09510832,  -29.70147414,    1.99043979])

# %%
points_y_predict = res_lsq.x[0] + res_lsq.x[1] * points_x + res_lsq.x[2] * points_x**2
plt.scatter(points_x, points_y)
plt.plot(points_x, points_y_predict)

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(x, a, b, c):
    return a * x**2 + b * x + c

xdata = np.linspace(0, 4, 50)
y = func(xdata, 2.5, 1.3, 0.5)
ydata = y + 0.5 * np.random.normal(size=len(xdata))

popt, pcov = curve_fit(func, xdata, ydata)

print popt

func(xdata, *popt)

plt.scatter(xdata, ydata)
plt.plot(xdata, func(xdata, *popt), color='red')
plt.show()
# Out:
# [ 2.48549326  1.34641943  0.48681837]

# %%
def func(x, a, b, c):
    return a * np.exp(-b * x) + c

xdata = np.linspace(0, 4, 50)
y = func(xdata, 2.5, 1.3, 0.5)
ydata = y + 0.5 * np.random.normal(size=len(xdata))

popt, pcov = curve_fit(func, xdata, ydata)

print popt

func(xdata, *popt)

plt.scatter(xdata, ydata)
plt.plot(xdata, func(xdata, *popt), color='red')
plt.show()
# Out:
# [ 2.57832832  1.19442235  0.43883443]

# %%
def func(x, a, b, c):
    return a * np.sin(-b * x) + c

xdata = np.linspace(0, 4, 50)
y = func(xdata, 2.5, 1.3, 0.5)
ydata = y + 0.5 * np.random.normal(size=len(xdata))

popt, pcov = curve_fit(func, xdata, ydata)

print popt

func(xdata, *popt)

plt.scatter(xdata, ydata)
plt.plot(xdata, func(xdata, *popt), color='red')
plt.show()
# Out:
# [ 2.40425394  1.31489767  0.48787647]
