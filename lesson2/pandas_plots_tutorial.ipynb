# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pylab as plt
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD'))
df
# Out:
#             A         B         C         D
# 0   -0.337264  0.797875  1.063881  1.930091
# 1   -0.873324 -1.561982  1.056562 -0.953739
# 2   -1.469378 -0.668533 -0.804401  0.389653
# 3   -0.730889 -1.752161 -0.126318 -0.587141
# 4   -1.490864 -1.854331  0.690945 -0.580064
# 5   -0.766771 -1.741983  0.360965 -0.685739
# 6    1.008000 -0.372152  0.914129 -0.922882
# 7    0.718172 -1.503483 -0.286340  0.765413
# 8   -1.158041 -0.264462  0.281234  0.208732
# 9   -0.745582  0.196463 -0.957373 -0.647293
# 10   0.456172  1.000134  0.167420 -0.806763
# 11  -1.699715 -0.957046  0.476028 -0.031770
# 12   1.162509  0.898898 -0.781603 -0.271348
# 13   0.431036  0.387196  0.732924 -0.184742
# 14   3.195832 -0.729116 -0.085453  0.676221
# 15   0.945095  1.235814 -0.421623  0.492468
# 16   1.437361 -0.204183  0.867767 -0.764601
# 17   1.210422  1.065706  0.332478  0.144011
# 18   0.980823 -0.113228 -0.478282 -1.991289
# 19   0.297706 -0.144043  1.345369  0.273359
# ...

# %%
df.A.plot()

# %%
df2 = df.cumsum()
df2.plot()

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f70bd2af290>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70b7705550>]], dtype=object)

# %%
df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f70b7650a10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70b734c410>]], dtype=object)

# %%
df2.corr()
# Out:
#           A         B         C         D
# A  1.000000 -0.576125 -0.350646 -0.412522
# B -0.576125  1.000000 -0.096558  0.058668
# C -0.350646 -0.096558  1.000000  0.881856
# D -0.412522  0.058668  0.881856  1.000000

# %%
df.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.005943     0.001309    -0.042889    -0.051624
# std       1.005436     1.002079     1.012497     1.022552
# min      -2.582489    -3.312386    -3.244115    -2.852319
# 25%      -0.749333    -0.665059    -0.740069    -0.717529
# 50%      -0.041242     0.029503    -0.043714    -0.091832
# 75%       0.665024     0.680715     0.670850     0.595576
# max       3.338723     3.578757     2.934885     3.946110

# %%
df2.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      3.245238    -8.307158   -17.655114   -29.132581
# std       7.877634     8.923228    18.044408    20.071281
# min     -15.467671   -27.776201   -54.156098   -65.745172
# 25%      -2.344675   -15.952223   -26.447398   -49.993711
# 50%       4.243289    -7.539824   -16.674032   -22.971979
# 75%       8.961149    -0.646173    -6.303220   -12.294906
# max      22.853775     9.983183    15.731098     8.674675

# %%
df.boxplot()

# %%
df2.boxplot()

# %%
df.loc[0:10,:].plot.area(stacked=False)

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
ax = df.plot.scatter(x='a', y='b', color='Blue', label='Group 1');
df.plot.scatter(x='c', y='d', color='Green', label='Group 2', ax=ax);

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series.plot.pie(figsize=(6, 6))

# %%
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde');

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))
autocorrelation_plot(data)

# %%
plt.plot(0.7 * np.random.rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.random.randn(1000))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.random.randn(1000)).cumsum()
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.sin(np.linspace(0,10,1000)))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.sin(np.random.randn(1000)))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import lag_plot
plt.figure()
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))
lag_plot(data)

# %%
data.loc[0:100].plot()

# %%
data = pd.Series(np.random.randn(1000))
lag_plot(data)

# %%
data = pd.Series(np.sin(np.random.randn(1000)))
lag_plot(data)

# %%
from pandas.tools.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))

bootstrap_plot(data, size=50, color='grey')
