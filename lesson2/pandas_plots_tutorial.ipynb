hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf2a497910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf2a362390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf2a19f210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf2a181790>]], dtype=object)

# %%
df2.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf2a3d9410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf29e6b3d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf29ded250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf29d4f850>]], dtype=object)

# %%
df2.corr()
# Out:
#           A         B         C         D
# A  1.000000 -0.440187 -0.791868  0.644291
# B -0.440187  1.000000  0.280441  0.120553
# C -0.791868  0.280441  1.000000 -0.573401
# D  0.644291  0.120553 -0.573401  1.000000

# %%
df.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.042863     0.002703    -0.088791     0.027078
# std       1.005435     1.000598     1.002771     1.004720
# min      -2.821215    -3.275892    -3.139745    -3.057695
# 25%      -0.676441    -0.661289    -0.783197    -0.632831
# 50%       0.041565    -0.017556    -0.074210     0.015685
# 75%       0.741897     0.637192     0.579990     0.658884
# max       2.794987     3.236815     3.528079     3.202071

# %%
df2.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     23.232304    11.665679   -62.973767    24.718291
# std       9.411094     8.122402    28.653977    10.037293
# min      -2.746609   -12.472770   -95.306418    -9.313503
# 25%      17.853714     6.850118   -86.975550    19.809217
# 50%      23.705225    13.040198   -71.214519    25.548312
# 75%      29.505695    17.360068   -52.501719    31.218728
# max      43.046379    26.683564     1.717314    45.803151

# %%
df.boxplot()

# %%
df2.boxplot()

# %%
df.loc[0:10,:].plot.area(stacked=False)

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])
ax = df.plot.scatter(x='a', y='b', color='Blue', label='Group 1');
df.plot.scatter(x='c', y='d', color='Green', label='Group 2', ax=ax);

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')
series.plot.pie(figsize=(6, 6))

# %%
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])
scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7faf296dad90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf294720d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf293f57d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf29361a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf29193c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf2916d410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf2907c5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28fff450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf28fef410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28f71290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28f30150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28ea6f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7faf28e5fa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28d98c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28d1aa90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7faf28c80f90>]], dtype=object)

# %%
ser = pd.Series(np.random.randn(1000))
ser.plot.kde()

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.random.randn(1000))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.random.randn(1000)).cumsum()
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.sin(np.linspace(0,10,1000)))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import autocorrelation_plot

plt.figure()
data = pd.Series(np.sin(np.random.randn(1000)))
autocorrelation_plot(data)

# %%
from pandas.tools.plotting import lag_plot
plt.figure()
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))
lag_plot(data)

# %%
data.loc[0:100].plot()

# %%
data = pd.Series(np.random.randn(1000))
lag_plot(data)

# %%
data = pd.Series(np.sin(np.random.randn(1000)))
lag_plot(data)

# %%
from pandas.tools.plotting import bootstrap_plot
data = pd.Series(np.random.rand(1000))

bootstrap_plot(data, size=50, color='grey')
