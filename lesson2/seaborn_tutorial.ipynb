# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.random.normal(size=100)
plt.hist(x)
# Out:
# (array([  1.,   5.,  15.,  19.,  17.,  14.,  11.,  11.,   5.,   2.]),
#  array([-2.34030019, -1.85005746, -1.35981473, -0.869572  , -0.37932927,
#          0.11091346,  0.6011562 ,  1.09139893,  1.58164166,  2.07188439,
#          2.56212712]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns
import pandas as pd
from scipy import stats, integrate

# %%
x = np.random.normal(size=100)
plt.hist(x)
# Out:
# (array([  2.,   3.,   7.,   8.,  20.,  18.,  20.,  15.,   5.,   2.]),
#  array([-2.68490747, -2.17676488, -1.6686223 , -1.16047972, -0.65233713,
#         -0.14419455,  0.36394804,  0.87209062,  1.38023321,  1.88837579,
#          2.39651837]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(x);

# %%
mean = [0, 1] 
cov = [(1, .5), 
       (.5, 1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=["x", "y"])

# %%
data
# Out:
# array([[  1.26518194e+00,   2.37461851e+00],
#        [  8.06190367e-01,   2.30033801e+00],
#        [  6.34489951e-01,   1.66888615e+00],
#        [ -1.50995169e+00,  -3.13229530e-01],
#        [ -9.19933749e-01,   2.87207210e+00],
#        [ -1.71920977e-01,   7.48998151e-01],
#        [ -2.91320478e-01,   7.72240035e-01],
#        [  1.28762465e+00,   1.07776836e+00],
#        [ -1.46654691e+00,   1.84216503e-01],
#        [  6.21565963e-01,   2.99388022e+00],
#        [  7.74890474e-01,   7.74380240e-01],
#        [ -1.31248640e+00,  -5.32848385e-01],
#        [ -2.53337404e-01,  -7.13249671e-01],
#        [  4.29162247e-01,   1.96725824e+00],
#        [ -9.21599406e-01,   1.62709031e+00],
#        [  1.09762208e-01,   4.70921496e-01],
#        [ -4.68667276e-01,   1.30993293e+00],
#        [  1.25814448e+00,  -6.06008350e-02],
#        [ -9.63575163e-01,   5.78388241e-01],
#        [  1.24449612e-03,   4.19742912e-01],
#        [ -4.32565380e-01,   7.32309470e-01],
# ...

# %%
sns.jointplot(x=data[:,0], y=data[:,1]);

# %%
sns.jointplot(x=data[:,0], y=data[:,1], kind='hex');

# %%
sns.jointplot(x="x", y="y", data=df, kind="kde");

# %%
p = sns.jointplot(x="x", y="y", data=df, kind="kde", color='magenta');
p.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")

# %%
p = sns.jointplot(x="x", y="y", data=df, kind="kde", color='magenta');
p.plot_joint(plt.scatter, c="w", s=30, linewidth=1, marker="+")

p.ax_joint.collections[0].set_alpha(0)
p.set_axis_labels("$X$", "$Y$");

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# ...

# %%
sns.pairplot(iris);

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Blues_d", n_levels=6);
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
df = sns.load_dataset("anscombe")
df
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", size=4,
           scatter_kws={"s": 50, "alpha": 1})
